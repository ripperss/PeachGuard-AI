# %%
# !nvidia-smi
# Out:
# Fri May 22 06:26:06 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/ripperss/PeachGuard-AI.git
# %cd PeachGuard-AI
# Out:
# fatal: destination path 'PeachGuard-AI' already exists and is not an empty directory.
# /content/PeachGuard-AI

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !tar -xzf /content/drive/MyDrive/peachguard-data.tar.gz

# %%
# !find data/processed/images/train -type f | wc -l
# !find data/processed/labels/train -type f | wc -l
# !find data/processed/images/val -type f | wc -l
# !find data/processed/labels/val -type f | wc -l
# Out:
# 2209
# 2209
# 301
# 301

# %%
# !pip install uv

# %%
# !uv sync
# Out:
# Resolved 55 packages in 1ms
# Checked 54 packages in 0.67ms

# %%
# !MPLBACKEND=Agg uv run python -m peachguard.cli.train \
  --config configs/train.yaml \
  --epochs 100 \
  --batch 16 \
  --workers 2 \
  --patience 30 \
  --output-dir /content/drive/MyDrive/peachguard-runs \
  --run-name yolo11n-100e \
  --save-period 10 \
  --exist-ok
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.51 🚀 Python-3.14.5 torch-2.12.0+cu130 CUDA:0 (Tesla T4, 14913MiB)
# ...
